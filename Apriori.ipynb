# %% [markdown]
# # Apriori

# %%
#importing all the neccessary libraries
import pandas as pd
import numpy as np
from itertools import combinations

# %%
def read_file_and_prepare_data(filename="BestBuy.csv",colname = "Transaction"):

    read_df = pd.read_csv(filename)
    lst=[]
    for i in read_df[colname]:
        lst += [i.split(',')]
    unique=[]
    list1=[]
    for a in lst:
        l1=[]
        for b in a:
            b= b.lstrip().rstrip()
            l1+=[b]
            if b not in unique:
                unique+=[b]
        l1.sort()
        list1+=[l1]
        unique.sort()
        list2=[]
    global dict1, key_list,val_list, X
    dict1 = { unique[i] : i for i in range(0, len(unique) ) }
    key_list = list(dict1.keys())
    val_list = list(dict1.values())

    for a in list1:
        l1 = []
        for b in a:
            l1 += [dict1[b]]
        list2 += [l1]
    return np.array(list2)

# %%
def freq_itemset(X, itemset, min_support):

    items = {}
    for a in X:
        for item in itemset:
            if item.issubset(a):
                if item not in items: 
                    items[item] = 1
                else: 
                    items[item] += 1    
    
    rows = X.shape[0]
    frequentset = []
    item_support = {}
    for item in items:
        s = items[item] / rows
        if s >= min_support:
            frequentset.append(item)
        
        item_support[item] = s
        
    return frequentset, item_support

# %%
def support(X, min_support=0.5):

    itemset1 = []
    for i in X:
        for j in i:
            j = frozenset([j])
            if j not in itemset1:
                itemset1.append(j)
    
    fi, item_support_dict = freq_itemset(X, itemset1, min_support)
    fitems = [fi]
    freq=[]
    k = 0
    while len(fitems[k]) > 0:
        fi = fitems[k]
        itemset = []
        if k == 0:
            for a, b in combinations(fi, 2):
                item = a | b
                itemset.append(item)
        else:    
            for a, b in combinations(fi, 2):       
                intersection = a & b
                if len(intersection) == k:
                    item = a | b
                    if item not in itemset:
                        itemset.append(item)     
       
        fi, supportitems = freq_itemset(X, itemset, min_support)
        fitems.append(fi)
        item_support_dict.update(supportitems)
        k += 1
    freq_print = convert_numbers_to_names(fitems)
    return freq_print,fitems, item_support_dict

# %%
def confidence(fitems, item_support_dict, min_confidence):

    association_rules = []
    for index, freq in enumerate(fitems[1:(len(fitems) - 1)]):
        for freq_set in freq:
            subsets = [frozenset([item]) for item in freq_set]
            rules, denominator = conf( item_support_dict, 
                                                  freq_set, subsets, min_confidence)
            association_rules.extend(rules)

            if index != 0:
                k = 0
                while len(denominator[0]) < len(freq_set) - 1:
                    itemset = []
                    if k == 0:
                        for a, b in combinations(denominator, 2):
                            item = a | b
                            itemset.append(item)
                    else:    
                        for a, b in combinations(denominator, 2):       
                            intersection = a & b
                            if len(intersection) == k:
                                item = a | b
                                if item not in itemset:
                                    itemset.append(item)     
                    
                    
                    rules, denominator = conf( item_support_dict,
                                                          freq_set, itemset, min_confidence)
                    association_rules.extend(rules)
                    k += 1   
    rules_df = pd.DataFrame(association_rules,columns=['First_item',"buys","Second_item","confidence_value"])
    list_first_item = [list(rules_df['First_item'])]
    list_second_item = [list(rules_df['Second_item'])]
    rules_df["First_item"] = convert_numbers_to_names(list_first_item)
    rules_df["Second_item"] = convert_numbers_to_names(list_second_item)
    return rules_df

# %%
def conf( item_support_dict, fset, sets, min_confidence=0.5):

    rules = []
    denominator = []
    
    for a in sets:
        b = fset - a
        cv = item_support_dict[fset] / item_support_dict[b]
        if cv >= min_confidence:
            info = b,"->", a, cv
            rules.append(info)
            denominator.append(a)
            
    return rules, denominator

# %%
def convert_numbers_to_names(ck):

    list_ = [list(x) for x in ck]
    len1 = (len(list_))
    list_form=[]
    for i in range(0,len1):
        if len(list_[i]) >= 1:
            list_form1 = list_[i]
            form=[]
            for innerlist in list_form1:
                a=[]
                for i in innerlist:
                    position = val_list.index(i)
                    a += [key_list[position]]
                form += [a]
            list_form +=form
    return list_form

# %%
def run():
    file = input("Enter the File Name(CSV) [if in different directory please provide the address with the file]\n")
    if ".xlsx" in file:
        read_file = pd.read_excel(file)
        read_file.to_csv (file, index = None, header=True)
    X = read_file_and_prepare_data(file)
    while True:
        try:
            min_support = float(input("Enter the SUPPORT value in the range of (0.0 - 1.0) : "))
            if min_support >=0.0 and min_support <=1.0:
                break
        except:
            min_support = 0.5
    while True:
        try:
            min_confidence = float(input("Enter the CONFIDENCE value in the range of (0.0 - 1.0) : "))
            if min_confidence >= 0.0 and min_confidence <= 1.0:
                break
        except:
            min_confidence = 0.5
    freq_print,freq_items, item_support_dict = support (X, min_support)
    print("-"*120)
    print("The Minimum support value is : ",min_support)
    print("The Minimum Confidence value is : ",min_confidence)
    print("-"*120)
    print("The Frequent itemset which is above or equal to the given support value: \n")
    print(freq_print)
    rules_df = confidence(freq_items, item_support_dict, min_confidence)
    print("-"*120)
    print("The rules with their confidence values are : \n")
    print(rules_df)
    rules_df.to_csv("output.csv")
    print("-"*120)
    print("The rules with their confidence value are available in output.csv file")
    print("-"*120)
    print("-"*120)

# %%
run()
# Out:
# Enter the File Name(CSV) [if in different directory please provide the address with the file]
# files/Nike.csv
# C:\Users\kavya\AppData\Local\Temp/ipykernel_15588/638295602.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(list2)
# Enter the SUPPORT value in the range of (0.0 - 1.0) : 0.3
# Enter the CONFIDENCE value in the range of (0.0 - 1.0) : 0.45
# ------------------------------------------------------------------------------------------------------------------------
# The Minimum support value is :  0.3
# The Minimum Confidence value is :  0.45
# ------------------------------------------------------------------------------------------------------------------------
# The Frequent itemset which is above or equal to the given support value:
#
# [['Modern Pants'], ['Running Shoe'], ['Socks'], ['Sweatshirts'], ['Soccer Shoe'], ['Hoodies'], ['Rash Guard'], ['Tech Pants'], ['Swimming Shirt'], ['Dry Fit V-Nick'], ['Modern Pants', 'Running Shoe'], ['Modern Pants', 'Socks'], ['Sweatshirts', 'Modern Pants'], ['Running Shoe', 'Socks'], ['Sweatshirts', 'Running Shoe'], ['Sweatshirts', 'Socks'], ['Modern Pants', 'Rash Guard'], ['Tech Pants', 'Modern Pants'], ['Rash Guard', 'Running Shoe'], ['Tech Pants', 'Running Shoe'], ['Rash Guard', 'Socks'], ['Tech Pants', 'Socks'], ['Sweatshirts', 'Rash Guard'], ['Sweatshirts', 'Tech Pants'], ['Hoodies', 'Rash Guard'], ['Hoodies', 'Tech Pants'], ['Tech Pants', 'Rash Guard'], ['Swimming Shirt', 'Hoodies'], ['Dry Fit V-Nick', 'Hoodies'], ['Swimming Shirt', 'Rash Guard'], ['Dry Fit V-Nick', 'Rash Guard'], ['Swimming Shirt', 'Tech Pants'], ['Dry Fit V-Nick', 'Tech Pants'], ['Swimming Shirt', 'Dry Fit V-Nick'], ['Swimming Shirt', 'Running Shoe'], ['Modern Pants', 'Running Shoe', 'Socks'], ['Sweatshirts', 'Modern Pants', 'Running Shoe'], ['Sweatshirts', 'Modern Pants', 'Socks'], ['Sweatshirts', 'Running Shoe', 'Socks'], ['Modern Pants', 'Rash Guard', 'Socks'], ['Tech Pants', 'Modern Pants', 'Socks'], ['Sweatshirts', 'Modern Pants', 'Rash Guard'], ['Sweatshirts', 'Tech Pants', 'Modern Pants'], ['Sweatshirts', 'Rash Guard', 'Socks'], ['Sweatshirts', 'Tech Pants', 'Socks'], ['Tech Pants', 'Modern Pants', 'Rash Guard'], ['Tech Pants', 'Rash Guard', 'Running Shoe'], ['Tech Pants', 'Rash Guard', 'Socks'], ['Sweatshirts', 'Tech Pants', 'Rash Guard'], ['Hoodies', 'Tech Pants', 'Rash Guard'], ['Swimming Shirt', 'Hoodies', 'Rash Guard'], ['Dry Fit V-Nick', 'Hoodies', 'Rash Guard'], ['Swimming Shirt', 'Hoodies', 'Tech Pants'], ['Dry Fit V-Nick', 'Hoodies', 'Tech Pants'], ['Swimming Shirt', 'Tech Pants', 'Rash Guard'], ['Dry Fit V-Nick', 'Tech Pants', 'Rash Guard'], ['Swimming Shirt', 'Hoodies', 'Dry Fit V-Nick'], ['Swimming Shirt', 'Rash Guard', 'Dry Fit V-Nick'], ['Swimming Shirt', 'Tech Pants', 'Dry Fit V-Nick'], ['Swimming Shirt', 'Rash Guard', 'Running Shoe'], ['Modern Pants', 'Running Shoe', 'Socks', 'Sweatshirts'], ['Modern Pants', 'Rash Guard', 'Socks', 'Sweatshirts'], ['Modern Pants', 'Socks', 'Sweatshirts', 'Tech Pants'], ['Modern Pants', 'Rash Guard', 'Socks', 'Tech Pants'], ['Modern Pants', 'Rash Guard', 'Sweatshirts', 'Tech Pants'], ['Rash Guard', 'Socks', 'Sweatshirts', 'Tech Pants'], ['Hoodies', 'Rash Guard', 'Swimming Shirt', 'Tech Pants'], ['Dry Fit V-Nick', 'Hoodies', 'Rash Guard', 'Tech Pants'], ['Dry Fit V-Nick', 'Hoodies', 'Rash Guard', 'Swimming Shirt'], ['Dry Fit V-Nick', 'Hoodies', 'Swimming Shirt', 'Tech Pants'], ['Dry Fit V-Nick', 'Rash Guard', 'Swimming Shirt', 'Tech Pants'], ['Modern Pants', 'Rash Guard', 'Socks', 'Sweatshirts', 'Tech Pants'], ['Dry Fit V-Nick', 'Hoodies', 'Rash Guard', 'Swimming Shirt', 'Tech Pants']]
# ------------------------------------------------------------------------------------------------------------------------
# The rules with their confidence values are :
#
#            First_item buys                                        Second_item  \
# 0      [Running Shoe]   ->                                     [Modern Pants]
# 1      [Modern Pants]   ->                                     [Running Shoe]
# 2             [Socks]   ->                                     [Modern Pants]
# 3      [Modern Pants]   ->                                            [Socks]
# 4      [Modern Pants]   ->                                      [Sweatshirts]
# ..                ...  ...                                                ...
# 405      [Tech Pants]   ->  [Dry Fit V-Nick, Hoodies, Rash Guard, Swimming...
# 406  [Swimming Shirt]   ->  [Dry Fit V-Nick, Hoodies, Rash Guard, Tech Pants]
# 407      [Rash Guard]   ->  [Dry Fit V-Nick, Hoodies, Swimming Shirt, Tech...
# 408         [Hoodies]   ->  [Dry Fit V-Nick, Rash Guard, Swimming Shirt, T...
# 409  [Dry Fit V-Nick]   ->  [Hoodies, Rash Guard, Swimming Shirt, Tech Pants]
#
#      confidence_value
# 0            0.642857
# 1            0.900000
# 2            0.692308
# 3            0.900000
# 4            1.000000
# ..                ...
# 405          0.666667
# 406          0.545455
# 407          0.500000
# 408          0.750000
# 409          0.666667
#
# [410 rows x 4 columns]
# ------------------------------------------------------------------------------------------------------------------------
# The rules with their confidence value are available in output.csv file
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
